# %%
import sys
sys.path.append("../")
import logging

import utils.nextcloud
from utils.targets import Zielwert

var_path = r"EE\6_Daten\Quartiere"
letztstand = r"EE\6_Daten\Quartiere\Quartiersvergleich211129cleaned.xlsx"
sheet_name = "PEExcel Import"
index_col = "longname"
file = utils.nextcloud.get(letztstand)

# %%
import pandas as pd
from openpyxl import load_workbook

df = pd.read_excel(file, sheet_name=sheet_name, header=2, index_col=index_col)
df2 = pd.read_excel(r"Quartiersvergleich_bruessel.xlsx", sheet_name=sheet_name, header=0, index_col=index_col)

# %%
df2
# Out:
#                            PE_Saldo  GFZ  PE-Saldo Zielwert [kWh/m²NGF]  \
# longname
# Foyer Laekenois - Basic      -143.0  1.3                              8
# Foyer Laekenois - AC 2050       NaN  1.3                              8
# Foyer Laekenois - Al 2040       NaN  1.3                              8
# Foyer Laekenois - Al 2050       NaN  1.3                              8
# Masui - Basic                   NaN  2.9                             25
# Masui - AC 2050                 NaN  2.9                             25
# Masui - Al 2040                 NaN  2.9                             25
# Masui - Al 2050                 NaN  2.9                             25
# Maximilien - Basic              NaN  4.0                             31
# Maximilien - AC 2050            NaN  4.0                             31
# Maximilien - Al 2040            NaN  4.0                             31
# Maximilien - Al 2050            NaN  4.0                             31
# Vergotedok - Basic              NaN  1.0                            -24
# Vergotedok - AC 2050            NaN  1.0                            -24
# Vergotedok - Al 2040            NaN  1.0                            -24
# Vergotedok - Al 2050            NaN  1.0                            -24
#
#                            PE-Saldo Ziel Real[kWh/m²BGF]  \
# longname
# Foyer Laekenois - Basic                             -135
# Foyer Laekenois - AC 2050                            -75
# Foyer Laekenois - Al 2040                            -79
# Foyer Laekenois - Al 2050                            -72
# Masui - Basic                                       -261
# Masui - AC 2050                                      -57
# Masui - Al 2040                                      -67
# Masui - Al 2050                                      -49
# Maximilien - Basic                                  -141
# Maximilien - AC 2050                                 -48
# Maximilien - Al 2040                                 -61
# Maximilien - Al 2050                                 -44
# Vergotedok - Basic                                  -238
# Vergotedok - AC 2050                                -108
# Vergotedok - Al 2040                                -123
# Vergotedok - Al 2050                                -115
#
#                            PE-Saldo Zielwert Großkraftwerke [kWh/m²NGF]
# longname
# Foyer Laekenois - Basic                                            -143
# Foyer Laekenois - AC 2050                                           -83
# Foyer Laekenois - Al 2040                                           -87
# Foyer Laekenois - Al 2050                                           -80
# Masui - Basic                                                      -286
# Masui - AC 2050                                                     -82
# Masui - Al 2040                                                     -92
# Masui - Al 2050                                                     -74
# Maximilien - Basic                                                 -172
# Maximilien - AC 2050                                                -79
# Maximilien - Al 2040                                                -92
# Maximilien - Al 2050                                                -75
# Vergotedok - Basic                                                 -214
# Vergotedok - AC 2050                                                -84
# Vergotedok - Al 2040                                                -99
# Vergotedok - Al 2050                                                -91

# %%
# clean
# remove empty rows
# remove outdated rows:
# rows that do not have Simualtion = "Doppelsimulation"
df = df.drop(df[(df.FILE != "latest")].index)
df
# Out:
#                                                     idx  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                1
# Aichinger 2 Alpha - Aktuell                           2
# Aichinger 3 Alpha - Netzdienlichkeit                  3
# Aichinger 4 Alpha - Min PEQ                           4
# Aichinger 5 Beta - Bauträger Standard                 5
# ...                                                 ...
# Glan 9Mob Omega - Bauträger Standard               9Mob
# Glan 10Mob Omega - Aktuell                        10Mob
# Glan 11Mob Omega - Netzdienlichkeit               11Mob
# Glan 12Mob Omega - Min PEQ                        12Mob
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom  12,5Mob
#
#                                                                     Variantenname  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                 Alpha - Bauträger Standard
# Aichinger 2 Alpha - Aktuell                                       Alpha - Aktuell
# Aichinger 3 Alpha - Netzdienlichkeit                     Alpha - Netzdienlichkeit
# Aichinger 4 Alpha - Min PEQ                                       Alpha - Min PEQ
# Aichinger 5 Beta - Bauträger Standard                   Beta - Bauträger Standard
# ...                                                                           ...
# Glan 9Mob Omega - Bauträger Standard                   Omega - Bauträger Standard
# Glan 10Mob Omega - Aktuell                                        Omega - Aktuell
# Glan 11Mob Omega - Netzdienlichkeit                      Omega - Netzdienlichkeit
# Glan 12Mob Omega - Min PEQ                                        Omega - Min PEQ
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom  Omega - Min PEQ - 75% Nutzerstrom
#
#                                                       Simulation  \
# longname
# Aichinger 1 Alpha - Bauträger Standard          Doppelsimulation
# Aichinger 2 Alpha - Aktuell                     Doppelsimulation
# Aichinger 3 Alpha - Netzdienlichkeit            Doppelsimulation
# Aichinger 4 Alpha - Min PEQ                     Doppelsimulation
# Aichinger 5 Beta - Bauträger Standard           Doppelsimulation
# ...                                                          ...
# Glan 9Mob Omega - Bauträger Standard            Doppelsimulation
# Glan 10Mob Omega - Aktuell                      Doppelsimulation
# Glan 11Mob Omega - Netzdienlichkeit             Doppelsimulation
# Glan 12Mob Omega - Min PEQ                      Doppelsimulation
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom  Doppelsimulation
#
#                                                Berechnungszeitpunkt    FILE  \
# longname
# Aichinger 1 Alpha - Bauträger Standard          2021-11-24 15:11:57  latest
# Aichinger 2 Alpha - Aktuell                     2021-11-24 15:12:07  latest
# Aichinger 3 Alpha - Netzdienlichkeit            2021-11-24 15:12:18  latest
# Aichinger 4 Alpha - Min PEQ                     2021-11-24 15:12:31  latest
# Aichinger 5 Beta - Bauträger Standard           2021-11-24 15:12:45  latest
# ...                                                             ...     ...
# Glan 9Mob Omega - Bauträger Standard                   44516.439213  latest
# Glan 10Mob Omega - Aktuell                             44516.439387  latest
# Glan 11Mob Omega - Netzdienlichkeit                    44516.439525  latest
# Glan 12Mob Omega - Min PEQ                             44516.439641  latest
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom         44516.439769  latest
#
#                                                   Projekt  Wohnbau NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard          Aichinger             123.8
# Aichinger 2 Alpha - Aktuell                     Aichinger             123.8
# Aichinger 3 Alpha - Netzdienlichkeit            Aichinger             123.8
# Aichinger 4 Alpha - Min PEQ                     Aichinger             123.8
# Aichinger 5 Beta - Bauträger Standard           Aichinger             123.8
# ...                                                   ...               ...
# Glan 9Mob Omega - Bauträger Standard                 Glan           38994.0
# Glan 10Mob Omega - Aktuell                           Glan           38994.0
# Glan 11Mob Omega - Netzdienlichkeit                  Glan           38994.0
# Glan 12Mob Omega - Min PEQ                           Glan           38994.0
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom       Glan           38994.0
#
#                                                 Büro NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                    0.0
# Aichinger 2 Alpha - Aktuell                               0.0
# Aichinger 3 Alpha - Netzdienlichkeit                      0.0
# Aichinger 4 Alpha - Min PEQ                               0.0
# Aichinger 5 Beta - Bauträger Standard                     0.0
# ...                                                       ...
# Glan 9Mob Omega - Bauträger Standard                      0.0
# Glan 10Mob Omega - Aktuell                                0.0
# Glan 11Mob Omega - Netzdienlichkeit                       0.0
# Glan 12Mob Omega - Min PEQ                                0.0
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom            0.0
#
#                                                 Schule NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                      0.0
# Aichinger 2 Alpha - Aktuell                                 0.0
# Aichinger 3 Alpha - Netzdienlichkeit                        0.0
# Aichinger 4 Alpha - Min PEQ                                 0.0
# Aichinger 5 Beta - Bauträger Standard                       0.0
# ...                                                         ...
# Glan 9Mob Omega - Bauträger Standard                        0.0
# Glan 10Mob Omega - Aktuell                                  0.0
# Glan 11Mob Omega - Netzdienlichkeit                         0.0
# Glan 12Mob Omega - Min PEQ                                  0.0
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom              0.0
#
#                                                 Kiga NGF (m²)  ...  \
# longname                                                       ...
# Aichinger 1 Alpha - Bauträger Standard                    0.0  ...
# Aichinger 2 Alpha - Aktuell                               0.0  ...
# Aichinger 3 Alpha - Netzdienlichkeit                      0.0  ...
# Aichinger 4 Alpha - Min PEQ                               0.0  ...
# Aichinger 5 Beta - Bauträger Standard                     0.0  ...
# ...                                                       ...  ...
# Glan 9Mob Omega - Bauträger Standard                    502.0  ...
# Glan 10Mob Omega - Aktuell                              502.0  ...
# Glan 11Mob Omega - Netzdienlichkeit                     502.0  ...
# Glan 12Mob Omega - Min PEQ                              502.0  ...
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom          502.0  ...
#
#                                                 Unnamed: 401  Unnamed: 402  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                   NaN           NaN
# Aichinger 2 Alpha - Aktuell                              NaN           NaN
# Aichinger 3 Alpha - Netzdienlichkeit                     NaN           NaN
# Aichinger 4 Alpha - Min PEQ                              NaN           NaN
# Aichinger 5 Beta - Bauträger Standard                    NaN           NaN
# ...                                                      ...           ...
# Glan 9Mob Omega - Bauträger Standard                     NaN           NaN
# Glan 10Mob Omega - Aktuell                               NaN           NaN
# Glan 11Mob Omega - Netzdienlichkeit                      NaN           NaN
# Glan 12Mob Omega - Min PEQ                               NaN           NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom           NaN           NaN
#
#                                                 Projektkennwert alfa  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                           NaN
# Aichinger 2 Alpha - Aktuell                                      NaN
# Aichinger 3 Alpha - Netzdienlichkeit                             NaN
# Aichinger 4 Alpha - Min PEQ                                      NaN
# Aichinger 5 Beta - Bauträger Standard                            NaN
# ...                                                              ...
# Glan 9Mob Omega - Bauträger Standard                             NaN
# Glan 10Mob Omega - Aktuell                                       NaN
# Glan 11Mob Omega - Netzdienlichkeit                              NaN
# Glan 12Mob Omega - Min PEQ                                       NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                   NaN
#
#                                                 Grenzwert  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                NaN
# Aichinger 2 Alpha - Aktuell                           NaN
# Aichinger 3 Alpha - Netzdienlichkeit                  NaN
# Aichinger 4 Alpha - Min PEQ                           NaN
# Aichinger 5 Beta - Bauträger Standard                 NaN
# ...                                                   ...
# Glan 9Mob Omega - Bauträger Standard                  NaN
# Glan 10Mob Omega - Aktuell                            NaN
# Glan 11Mob Omega - Netzdienlichkeit                   NaN
# Glan 12Mob Omega - Min PEQ                            NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom        NaN
#
#                                                 Projektkennwert beta  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                           NaN
# Aichinger 2 Alpha - Aktuell                                      NaN
# Aichinger 3 Alpha - Netzdienlichkeit                             NaN
# Aichinger 4 Alpha - Min PEQ                                      NaN
# Aichinger 5 Beta - Bauträger Standard                            NaN
# ...                                                              ...
# Glan 9Mob Omega - Bauträger Standard                             NaN
# Glan 10Mob Omega - Aktuell                                       NaN
# Glan 11Mob Omega - Netzdienlichkeit                              NaN
# Glan 12Mob Omega - Min PEQ                                       NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                   NaN
#
#                                                 Grenzwert.1  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                  NaN
# Aichinger 2 Alpha - Aktuell                             NaN
# Aichinger 3 Alpha - Netzdienlichkeit                    NaN
# Aichinger 4 Alpha - Min PEQ                             NaN
# Aichinger 5 Beta - Bauträger Standard                   NaN
# ...                                                     ...
# Glan 9Mob Omega - Bauträger Standard                    NaN
# Glan 10Mob Omega - Aktuell                              NaN
# Glan 11Mob Omega - Netzdienlichkeit                     NaN
# Glan 12Mob Omega - Min PEQ                              NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom          NaN
#
#                                                 CO2 Personen Wohnen (t CO2 /Person a)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                            NaN
# Aichinger 2 Alpha - Aktuell                                                       NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                              NaN
# Aichinger 4 Alpha - Min PEQ                                                       NaN
# Aichinger 5 Beta - Bauträger Standard                                             NaN
# ...                                                                               ...
# Glan 9Mob Omega - Bauträger Standard                                              NaN
# Glan 10Mob Omega - Aktuell                                                        NaN
# Glan 11Mob Omega - Netzdienlichkeit                                               NaN
# Glan 12Mob Omega - Min PEQ                                                        NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                                    NaN
#
#                                                Grenzwert CO2 Person Wohnen  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                 NaN
# Aichinger 2 Alpha - Aktuell                                            NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                   NaN
# Aichinger 4 Alpha - Min PEQ                                            NaN
# Aichinger 5 Beta - Bauträger Standard                                  NaN
# ...                                                                    ...
# Glan 9Mob Omega - Bauträger Standard                                   NaN
# Glan 10Mob Omega - Aktuell                                             NaN
# Glan 11Mob Omega - Netzdienlichkeit                                    NaN
# Glan 12Mob Omega - Min PEQ                                             NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                         NaN
#
#                                                 CO2 Gesamt alle Nutzungen (kg CO2 /m² a)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                               NaN
# Aichinger 2 Alpha - Aktuell                                                          NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                                 NaN
# Aichinger 4 Alpha - Min PEQ                                                          NaN
# Aichinger 5 Beta - Bauträger Standard                                                NaN
# ...                                                                                  ...
# Glan 9Mob Omega - Bauträger Standard                                                 NaN
# Glan 10Mob Omega - Aktuell                                                           NaN
# Glan 11Mob Omega - Netzdienlichkeit                                                  NaN
# Glan 12Mob Omega - Min PEQ                                                           NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                                       NaN
#
#                                                 Grenzwert CO2 näherungsweise auf m² bezogen (UAP)
# longname
# Aichinger 1 Alpha - Bauträger Standard                                                        NaN
# Aichinger 2 Alpha - Aktuell                                                                   NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                                          NaN
# Aichinger 4 Alpha - Min PEQ                                                                   NaN
# Aichinger 5 Beta - Bauträger Standard                                                         NaN
# ...                                                                                           ...
# Glan 9Mob Omega - Bauträger Standard                                                          NaN
# Glan 10Mob Omega - Aktuell                                                                    NaN
# Glan 11Mob Omega - Netzdienlichkeit                                                           NaN
# Glan 12Mob Omega - Min PEQ                                                                    NaN
# Glan 12,5Mob Omega - Min PEQ - 75% Nutzerstrom                                                NaN
#
# [144 rows x 410 columns]

# %%
#plotting cols
req_cols = []
# system boundary
for sys in ["Alpha", "Beta", "Omega"]:
    df[sys] = [sys*bool for bool in df.Variantenname.str.contains(sys)]
df["Systemgrenze"] = df["Alpha"] + df["Beta"] + df["Omega"]
req_cols.append("Systemgrenze")

df = df.drop(df[(df.Systemgrenze == "Omega")].index)
df
# Out:
#                                                  idx  \
# longname
# Aichinger 1 Alpha - Bauträger Standard             1
# Aichinger 2 Alpha - Aktuell                        2
# Aichinger 3 Alpha - Netzdienlichkeit               3
# Aichinger 4 Alpha - Min PEQ                        4
# Aichinger 5 Beta - Bauträger Standard              5
# ...                                              ...
# Glan 5Mob Beta - Bauträger Standard             5Mob
# Glan 6Mob Beta - Aktuell                        6Mob
# Glan 7Mob Beta - Netzdienlichkeit               7Mob
# Glan 8Mob Beta - Min PEQ                        8Mob
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  8,5Mob
#
#                                                                  Variantenname  \
# longname
# Aichinger 1 Alpha - Bauträger Standard              Alpha - Bauträger Standard
# Aichinger 2 Alpha - Aktuell                                    Alpha - Aktuell
# Aichinger 3 Alpha - Netzdienlichkeit                  Alpha - Netzdienlichkeit
# Aichinger 4 Alpha - Min PEQ                                    Alpha - Min PEQ
# Aichinger 5 Beta - Bauträger Standard                Beta - Bauträger Standard
# ...                                                                        ...
# Glan 5Mob Beta - Bauträger Standard                  Beta - Bauträger Standard
# Glan 6Mob Beta - Aktuell                                        Beta - Aktuell
# Glan 7Mob Beta - Netzdienlichkeit                      Beta - Netzdienlichkeit
# Glan 8Mob Beta - Min PEQ                                        Beta - Min PEQ
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  Beta - Min PEQ - 75% Nutzerstrom
#
#                                                     Simulation  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        Doppelsimulation
# Aichinger 2 Alpha - Aktuell                   Doppelsimulation
# Aichinger 3 Alpha - Netzdienlichkeit          Doppelsimulation
# Aichinger 4 Alpha - Min PEQ                   Doppelsimulation
# Aichinger 5 Beta - Bauträger Standard         Doppelsimulation
# ...                                                        ...
# Glan 5Mob Beta - Bauträger Standard           Doppelsimulation
# Glan 6Mob Beta - Aktuell                      Doppelsimulation
# Glan 7Mob Beta - Netzdienlichkeit             Doppelsimulation
# Glan 8Mob Beta - Min PEQ                      Doppelsimulation
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  Doppelsimulation
#
#                                              Berechnungszeitpunkt    FILE  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        2021-11-24 15:11:57  latest
# Aichinger 2 Alpha - Aktuell                   2021-11-24 15:12:07  latest
# Aichinger 3 Alpha - Netzdienlichkeit          2021-11-24 15:12:18  latest
# Aichinger 4 Alpha - Min PEQ                   2021-11-24 15:12:31  latest
# Aichinger 5 Beta - Bauträger Standard         2021-11-24 15:12:45  latest
# ...                                                           ...     ...
# Glan 5Mob Beta - Bauträger Standard                  44516.438333  latest
# Glan 6Mob Beta - Aktuell                             44516.438461  latest
# Glan 7Mob Beta - Netzdienlichkeit                    44516.438646  latest
# Glan 8Mob Beta - Min PEQ                             44516.438796  latest
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom         44516.439005  latest
#
#                                                 Projekt  Wohnbau NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        Aichinger             123.8
# Aichinger 2 Alpha - Aktuell                   Aichinger             123.8
# Aichinger 3 Alpha - Netzdienlichkeit          Aichinger             123.8
# Aichinger 4 Alpha - Min PEQ                   Aichinger             123.8
# Aichinger 5 Beta - Bauträger Standard         Aichinger             123.8
# ...                                                 ...               ...
# Glan 5Mob Beta - Bauträger Standard                Glan           38994.0
# Glan 6Mob Beta - Aktuell                           Glan           38994.0
# Glan 7Mob Beta - Netzdienlichkeit                  Glan           38994.0
# Glan 8Mob Beta - Min PEQ                           Glan           38994.0
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom       Glan           38994.0
#
#                                               Büro NGF (m²)  Schule NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                  0.0              0.0
# Aichinger 2 Alpha - Aktuell                             0.0              0.0
# Aichinger 3 Alpha - Netzdienlichkeit                    0.0              0.0
# Aichinger 4 Alpha - Min PEQ                             0.0              0.0
# Aichinger 5 Beta - Bauträger Standard                   0.0              0.0
# ...                                                     ...              ...
# Glan 5Mob Beta - Bauträger Standard                     0.0              0.0
# Glan 6Mob Beta - Aktuell                                0.0              0.0
# Glan 7Mob Beta - Netzdienlichkeit                       0.0              0.0
# Glan 8Mob Beta - Min PEQ                                0.0              0.0
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom            0.0              0.0
#
#                                               Kiga NGF (m²)  ...  \
# longname                                                     ...
# Aichinger 1 Alpha - Bauträger Standard                  0.0  ...
# Aichinger 2 Alpha - Aktuell                             0.0  ...
# Aichinger 3 Alpha - Netzdienlichkeit                    0.0  ...
# Aichinger 4 Alpha - Min PEQ                             0.0  ...
# Aichinger 5 Beta - Bauträger Standard                   0.0  ...
# ...                                                     ...  ...
# Glan 5Mob Beta - Bauträger Standard                   502.0  ...
# Glan 6Mob Beta - Aktuell                              502.0  ...
# Glan 7Mob Beta - Netzdienlichkeit                     502.0  ...
# Glan 8Mob Beta - Min PEQ                              502.0  ...
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom          502.0  ...
#
#                                               Projektkennwert beta  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                         NaN
# Aichinger 2 Alpha - Aktuell                                    NaN
# Aichinger 3 Alpha - Netzdienlichkeit                           NaN
# Aichinger 4 Alpha - Min PEQ                                    NaN
# Aichinger 5 Beta - Bauträger Standard                          NaN
# ...                                                            ...
# Glan 5Mob Beta - Bauträger Standard                            NaN
# Glan 6Mob Beta - Aktuell                                       NaN
# Glan 7Mob Beta - Netzdienlichkeit                              NaN
# Glan 8Mob Beta - Min PEQ                                       NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                   NaN
#
#                                               Grenzwert.1  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                NaN
# Aichinger 2 Alpha - Aktuell                           NaN
# Aichinger 3 Alpha - Netzdienlichkeit                  NaN
# Aichinger 4 Alpha - Min PEQ                           NaN
# Aichinger 5 Beta - Bauträger Standard                 NaN
# ...                                                   ...
# Glan 5Mob Beta - Bauträger Standard                   NaN
# Glan 6Mob Beta - Aktuell                              NaN
# Glan 7Mob Beta - Netzdienlichkeit                     NaN
# Glan 8Mob Beta - Min PEQ                              NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom          NaN
#
#                                               CO2 Personen Wohnen (t CO2 /Person a)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                          NaN
# Aichinger 2 Alpha - Aktuell                                                     NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                            NaN
# Aichinger 4 Alpha - Min PEQ                                                     NaN
# Aichinger 5 Beta - Bauträger Standard                                           NaN
# ...                                                                             ...
# Glan 5Mob Beta - Bauträger Standard                                             NaN
# Glan 6Mob Beta - Aktuell                                                        NaN
# Glan 7Mob Beta - Netzdienlichkeit                                               NaN
# Glan 8Mob Beta - Min PEQ                                                        NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                                    NaN
#
#                                               Grenzwert CO2 Person Wohnen  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                NaN
# Aichinger 2 Alpha - Aktuell                                           NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                  NaN
# Aichinger 4 Alpha - Min PEQ                                           NaN
# Aichinger 5 Beta - Bauträger Standard                                 NaN
# ...                                                                   ...
# Glan 5Mob Beta - Bauträger Standard                                   NaN
# Glan 6Mob Beta - Aktuell                                              NaN
# Glan 7Mob Beta - Netzdienlichkeit                                     NaN
# Glan 8Mob Beta - Min PEQ                                              NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                          NaN
#
#                                               CO2 Gesamt alle Nutzungen (kg CO2 /m² a)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                             NaN
# Aichinger 2 Alpha - Aktuell                                                        NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                               NaN
# Aichinger 4 Alpha - Min PEQ                                                        NaN
# Aichinger 5 Beta - Bauträger Standard                                              NaN
# ...                                                                                ...
# Glan 5Mob Beta - Bauträger Standard                                                NaN
# Glan 6Mob Beta - Aktuell                                                           NaN
# Glan 7Mob Beta - Netzdienlichkeit                                                  NaN
# Glan 8Mob Beta - Min PEQ                                                           NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                                       NaN
#
#                                               Grenzwert CO2 näherungsweise auf m² bezogen (UAP)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                                                      NaN
# Aichinger 2 Alpha - Aktuell                                                                 NaN
# Aichinger 3 Alpha - Netzdienlichkeit                                                        NaN
# Aichinger 4 Alpha - Min PEQ                                                                 NaN
# Aichinger 5 Beta - Bauträger Standard                                                       NaN
# ...                                                                                         ...
# Glan 5Mob Beta - Bauträger Standard                                                         NaN
# Glan 6Mob Beta - Aktuell                                                                    NaN
# Glan 7Mob Beta - Netzdienlichkeit                                                           NaN
# Glan 8Mob Beta - Min PEQ                                                                    NaN
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                                                NaN
#
#                                               Alpha  Beta  Omega  Systemgrenze
# longname
# Aichinger 1 Alpha - Bauträger Standard        Alpha                      Alpha
# Aichinger 2 Alpha - Aktuell                   Alpha                      Alpha
# Aichinger 3 Alpha - Netzdienlichkeit          Alpha                      Alpha
# Aichinger 4 Alpha - Min PEQ                   Alpha                      Alpha
# Aichinger 5 Beta - Bauträger Standard                Beta                 Beta
# ...                                             ...   ...    ...           ...
# Glan 5Mob Beta - Bauträger Standard                  Beta                 Beta
# Glan 6Mob Beta - Aktuell                             Beta                 Beta
# Glan 7Mob Beta - Netzdienlichkeit                    Beta                 Beta
# Glan 8Mob Beta - Min PEQ                             Beta                 Beta
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom         Beta                 Beta
#
# [88 rows x 414 columns]

# %% [markdown]
# # project
# req_cols.append("Projekt")
# # mobility measures
# df["Mobilität"] = ["Klima:Aktiv Standard"* (not b) for b in df.idx.astype(str).str.contains("ob")]
# df["Mobilität"] += ["Optimiert"*b for b in df.idx.astype(str).str.contains("ob")]
# df["Mobilität"]

# %%
# PE-saldo Projektwert
# depends on energy system
df["id"] = df.idx.astype(str).str.extract("(^\d)").astype(int)
df.id
# Out:
# longname
# Aichinger 1 Alpha - Bauträger Standard          1
# Aichinger 2 Alpha - Aktuell                     2
# Aichinger 3 Alpha - Netzdienlichkeit            3
# Aichinger 4 Alpha - Min PEQ                     4
# Aichinger 5 Beta - Bauträger Standard           5
#                                                ..
# Glan 5Mob Beta - Bauträger Standard             5
# Glan 6Mob Beta - Aktuell                        6
# Glan 7Mob Beta - Netzdienlichkeit               7
# Glan 8Mob Beta - Min PEQ                        8
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom    8
# Name: id, Length: 88, dtype: int32

# %%
df["Energiesystem"] = ["Fernwärme"*bool for bool in df.id.floordiv(1).isin([1,5])]
df["Energiesystem"] += ["Wärmepumpe"*bool for bool in df.id.floordiv(1).isin([2,6])]
df["Energiesystem"] += ["WP mit DSM"*bool for bool in df.id.floordiv(1).isin([3,4,7,8])]
df.Energiesystem
# Out:
# longname
# Aichinger 1 Alpha - Bauträger Standard           Fernwärme
# Aichinger 2 Alpha - Aktuell                     Wärmepumpe
# Aichinger 3 Alpha - Netzdienlichkeit            WP mit DSM
# Aichinger 4 Alpha - Min PEQ                     WP mit DSM
# Aichinger 5 Beta - Bauträger Standard            Fernwärme
#                                                    ...
# Glan 5Mob Beta - Bauträger Standard              Fernwärme
# Glan 6Mob Beta - Aktuell                        Wärmepumpe
# Glan 7Mob Beta - Netzdienlichkeit               WP mit DSM
# Glan 8Mob Beta - Min PEQ                        WP mit DSM
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom    WP mit DSM
# Name: Energiesystem, Length: 88, dtype: object

# %%
#FW Block
offset_map = {
    "Fernwärme": {
            "PEBedarf": {"abc": "HQ", "num":224},
            "PEExport": {"abc": "HR", "num":225},
            "PESaldo": {"abc": "HS", "num":226},
            "Alpha - Dichteausgleich [kWh/m²NGF]": {
                "abc": "HU", "num":228},
        },
        "Wärmepumpe": {
            "PEBedarf": {"abc": "IK", "num":244},
            "PEExport": {"abc": "IL", "num":245},
            "PESaldo": {"abc": "IM", "num":246},
            "Alpha - Dichteausgleich [kWh/m²NGF]": {
                "abc": "IO", "num":248},
        },
        "WP mit DSM": {
            "PEBedarf": {"abc": "KW", "num":308},
            "PEExport": {"abc": "KX", "num":309},
            "PESaldo": {"abc": "KY", "num":310},
            "Alpha - Dichteausgleich [kWh/m²NGF]": {
                "abc": "LA", "num":312},
        }
}

df["saldo_offset"] = [-226 + offset_map[e]["PESaldo"]["num"] for e in df.Energiesystem]
df.saldo_offset
# Out:
# longname
# Aichinger 1 Alpha - Bauträger Standard           0
# Aichinger 2 Alpha - Aktuell                     20
# Aichinger 3 Alpha - Netzdienlichkeit            84
# Aichinger 4 Alpha - Min PEQ                     84
# Aichinger 5 Beta - Bauträger Standard            0
#                                                 ..
# Glan 5Mob Beta - Bauträger Standard              0
# Glan 6Mob Beta - Aktuell                        20
# Glan 7Mob Beta - Netzdienlichkeit               84
# Glan 8Mob Beta - Min PEQ                        84
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom    84
# Name: saldo_offset, Length: 88, dtype: int64

# %%
df["PE_Saldo"] = df.iloc[:, 226] * df.Energiesystem.str.contains("Fernwärme")
df["PE_Saldo"] += df.iloc[:, 246] * df.Energiesystem.str.contains("Wärmepumpe")
df["PE_Saldo"] += df.iloc[:, 310] * df.Energiesystem.str.contains("WP mit DSM")
df.PE_Saldo[df.Projekt=="Am Bichl"]
    # df.iloc[i, -1] = df.iloc[i, offset_map[df.loc[row,"Energiesystem"]]["PEBedarf"]["num"]-1]
# offsets=dict(fw=)
# Out:
# longname
# Am Bichl 1 Alpha - Bauträger Standard                   -97.727763
# Am Bichl 2 Alpha - Aktuell                               -3.461126
# Am Bichl 3 Alpha - Netzdienlichkeit                      48.692774
# Am Bichl 4 Alpha - Min PEQ                               29.080125
# Am Bichl 4.5 Alpha - Min PEQ - 75% Nutzerstrom           35.846388
# Am Bichl 5 Beta - Bauträger Standard                   -104.008996
# Am Bichl 6 Beta - Aktuell                               -11.794045
# Am Bichl 7 Beta - Netzdienlichkeit                       43.646689
# Am Bichl 8 Beta - Min PEQ                                24.665779
# Am Bichl 8.5 Beta - Min PEQ - 75% Nutzerstrom            31.268614
# Am Bichl 6 mobopt Beta - Aktuell                        -11.794045
# Am Bichl 7 mobopt Beta - Netzdienlichkeit                43.646689
# Am Bichl 8 mobopt Beta - Min PEQ                         24.665779
# Am Bichl 8,5 mobopt Beta - Min PEQ - Nutzerstrom 75%     31.268614
# Name: PE_Saldo, dtype: float64

# %%
from matplotlib import pyplot as plt
from utils.plotting_eng import target_of_gfz
import numpy as np
import seaborn as sns
import logging

logging.level=logging.WARNING

zq_zielwert = Zielwert.ZQSynergy()
fsi = np.linspace(0,6,100)
zw_df = pd.DataFrame()
zw_df["Target for PEQ Alpha"] = zq_zielwert.df(fsi)
zw_df[""] = np.zeros(len(fsi))
zw_df2 = pd.DataFrame()
zw_df2["Density context factor" "\n" "added or subtracted" "\n" "to PE-balance"] = zq_zielwert.df(fsi)
zw_df2[""] = np.zeros(len(fsi))

fig, ax = plt.subplots(1,1, figsize=(10,6))

target_of_gfz(ax, df=zw_df, xlims=(0,6), ylims=(-300,150), color=["red", "darkred"])
target_of_gfz(ax, df=-zw_df2, xlims=(0,6), ylims=(-300,150), color=["lightgreen", "darkred"], linestyle="dashed", linewidth=1)

df_plot = df[df.Systemgrenze=="Alpha"]
df_plot.Variantenname = df_plot.Variantenname.str\
    .replace("Alpha - ","")\
    .replace("Standard","")\
    .replace("Bauträger Standard", "Property developer" "\n" "standard")\
    .replace("Aktuell", "Current status of planning")\
    .replace("Netzdienlichkeit", "Network utility")
#    .replace("Beta - ","")\
 #   .replace("Standard","")\
  #  .replace("Min PEQ", "Min PED")\
   # .replace("Min PEQ - 75% Nutzerstrom", "Min PED - 75% User electricity demand")\
    #.replace("Bauträger", "Property developer")

sns.scatterplot(x="GFZ", y="PE_Saldo", data=df_plot, ax=ax, color="lightgrey")
sns.scatterplot(x="GFZ", y="PE_Saldo", data=df_plot[df_plot.Variantenname=="Min PEQ"],
                ax=ax, color="grey")


# sns.scatterplot(x=2.9, y=[25, -57, -82], data=[25, -57, -82], color="blue")
# sns.scatterplot(x=4.0, y=[31, -48, -79], data=[31, -48, -79], color="blue")
# sns.scatterplot(x=1.0, y=[-24, -108, -84], data=[-24, -108, -84], color="blue")
#
# sns.scatterplot(x=1.3, y=[8, -135, -143], data=[8, -135, -143], color="green")
# sns.scatterplot(x=2.9, y=[25, -261, -286], data=[25, -261, -286], color="green")
# sns.scatterplot(x=4.0, y=[31, -141, -172], data=[31, -141, -172], color="green")
# sns.scatterplot(x=1.0, y=[-24, -238, -214], data=[-24, -238, -214], color="green")
ax.set_ylabel("Primary energy balance \n(+Diff. to the target value)\n[$kWh/m²_{NFA}a$]")
fsis = [1.3,2.9,4.0,0.8]
pes = [-82, -84, -79,-86]
for pw, fsi in zip(pes,fsis):
        # GFZ marks
    minpeq = pw

    #gfz lines
    ax.plot((fsi, fsi),(-100,minpeq), linewidth=0.1, color="blue")
    ax.text(fsi-0.1, -300, round(fsi,2), fontsize=8)

    # min peq bubble
    zw = zq_zielwert.alpha(fsi)
    ax.plot((fsi, fsi), (zw, minpeq), color="red", linewidth=0.6)

    # d=0
    # if proj in ["Am Bichl", "Gneis"]:
    #     d = 20
    # #beschriftung MIn PEQ
    # s = f"{proj}: {round(minpeq)} (+{round(minpeq-zw)})"
    # s = f"{proj} "
    # ax.text(fsi+0.1, minpeq+d, s, fontsize=11, color="grey")
textcolor="teal"
#    ax.plot((1.3, 1.3, 1.3), (8, -75, -83), color="blue")
ax.text(1.4, -75, "Foyer Laekenois" "\n" "AC 2050" "\n" "-82, (-75)", color=textcolor)
#   ax.plot((2.9, 2.9, 2.9), (25, -57, -82), color="blue")
ax.text(3, -80, "Masui" "\n" "AC 2050" "\n" "-82 (-57)", color=textcolor)
#   ax.plot((4.0, 4.0, 4.0), (31, -48, -79), color="blue")
ax.text(3.8, -20, "Maximilien " "\n" " AC 2050" "\n" "-78 (-48)", color=textcolor)
#   ax.plot((1.0, 1.0, 1.0), (-24, -108, -84), color="blue")
ax.text(0.1, -170, "Vergotedok" "\n" "AC 2050" "\n" "-86 (-108)", color=textcolor)

sns.scatterplot(x=[1.3,2.9,4.0,0.8] , y=[-142, -285, -172,-214], color="red", label="Status-Quo")
sns.scatterplot(x=[1.3,2.9,4.0,0.8] , y=[-141, -261, -160,-201], color="orange", label="Basic")
sns.scatterplot(x=[1.3,2.9,4.0,0.8] , y=[-82, -84, -79,-86], color=textcolor, label="Ambitious Collective 2050")
sns.scatterplot(x=[1.3,2.9,4.0,0.8] , y=[-87, -92, -92,-99], color="lightgreen", label="Ambitious Individual 2040")
sns.scatterplot(x=[1.3,2.9,4.0,0.8] , y=[-80, -74, -75,-91], color="green", label="Ambitious Individual 2050")

plt.savefig("MinPEQ_eng.png", dpi=300)
# Out:
# C:\Users\Simon Schneider\AppData\Local\Temp\ipykernel_39132\1929481273.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot.Variantenname = df_plot.Variantenname.str\

# %%
df_plot = df[df.Systemgrenze=="Alpha"]
df_plot.Variantenname = df_plot.Variantenname.str\
    .replace("Alpha - ","")\
    .replace("Standard","")\
    .replace("Bauträger Standard", "Property developer" "\n" "standard")\
    .replace("Aktuell", "Current status of planning")\
    .replace("Netzdienlichkeit", "Network utility")
df_plot.to_excel("test.xlsx")
# Out:
# C:\Users\Simon Schneider\AppData\Local\Temp\ipykernel_39132\3023608391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot.Variantenname = df_plot.Variantenname.str\

# %%
new_names= {
  "Aichinger": "SF Detached housing",
    "Am Bichl": "Suburban residential 1",
    "Gneis": "Suburban residential 2",
    "Graz": "Urban mixed use",
    "Glan": "Urban residential",
    "Pilzgasse": "Dense urban mixed use"
}
df["District Energy Balance"] = df["Projekt"].map(new_names)
df["Floor area ratio (FAR)"] = df["GFZ"]
df["Primary Energy balance"]= df["PE_Saldo"]

# %%
sns.scatterplot(x="Floor area ratio (FAR)", y="Primary Energy balance", data=df[df.Systemgrenze=="Alpha"], hue="District Energy Balance")
# Out:
# <Axes: xlabel='Floor area ratio (FAR)', ylabel='Primary Energy balance'>

# %%
df
# Out:
#                                                  idx  \
# longname
# Aichinger 1 Alpha - Bauträger Standard             1
# Aichinger 2 Alpha - Aktuell                        2
# Aichinger 3 Alpha - Netzdienlichkeit               3
# Aichinger 4 Alpha - Min PEQ                        4
# Aichinger 5 Beta - Bauträger Standard              5
# ...                                              ...
# Glan 5Mob Beta - Bauträger Standard             5Mob
# Glan 6Mob Beta - Aktuell                        6Mob
# Glan 7Mob Beta - Netzdienlichkeit               7Mob
# Glan 8Mob Beta - Min PEQ                        8Mob
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  8,5Mob
#
#                                                                  Variantenname  \
# longname
# Aichinger 1 Alpha - Bauträger Standard              Alpha - Bauträger Standard
# Aichinger 2 Alpha - Aktuell                                    Alpha - Aktuell
# Aichinger 3 Alpha - Netzdienlichkeit                  Alpha - Netzdienlichkeit
# Aichinger 4 Alpha - Min PEQ                                    Alpha - Min PEQ
# Aichinger 5 Beta - Bauträger Standard                Beta - Bauträger Standard
# ...                                                                        ...
# Glan 5Mob Beta - Bauträger Standard                  Beta - Bauträger Standard
# Glan 6Mob Beta - Aktuell                                        Beta - Aktuell
# Glan 7Mob Beta - Netzdienlichkeit                      Beta - Netzdienlichkeit
# Glan 8Mob Beta - Min PEQ                                        Beta - Min PEQ
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  Beta - Min PEQ - 75% Nutzerstrom
#
#                                                     Simulation  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        Doppelsimulation
# Aichinger 2 Alpha - Aktuell                   Doppelsimulation
# Aichinger 3 Alpha - Netzdienlichkeit          Doppelsimulation
# Aichinger 4 Alpha - Min PEQ                   Doppelsimulation
# Aichinger 5 Beta - Bauträger Standard         Doppelsimulation
# ...                                                        ...
# Glan 5Mob Beta - Bauträger Standard           Doppelsimulation
# Glan 6Mob Beta - Aktuell                      Doppelsimulation
# Glan 7Mob Beta - Netzdienlichkeit             Doppelsimulation
# Glan 8Mob Beta - Min PEQ                      Doppelsimulation
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom  Doppelsimulation
#
#                                              Berechnungszeitpunkt    FILE  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        2021-11-24 15:11:57  latest
# Aichinger 2 Alpha - Aktuell                   2021-11-24 15:12:07  latest
# Aichinger 3 Alpha - Netzdienlichkeit          2021-11-24 15:12:18  latest
# Aichinger 4 Alpha - Min PEQ                   2021-11-24 15:12:31  latest
# Aichinger 5 Beta - Bauträger Standard         2021-11-24 15:12:45  latest
# ...                                                           ...     ...
# Glan 5Mob Beta - Bauträger Standard                  44516.438333  latest
# Glan 6Mob Beta - Aktuell                             44516.438461  latest
# Glan 7Mob Beta - Netzdienlichkeit                    44516.438646  latest
# Glan 8Mob Beta - Min PEQ                             44516.438796  latest
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom         44516.439005  latest
#
#                                                 Projekt  Wohnbau NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard        Aichinger             123.8
# Aichinger 2 Alpha - Aktuell                   Aichinger             123.8
# Aichinger 3 Alpha - Netzdienlichkeit          Aichinger             123.8
# Aichinger 4 Alpha - Min PEQ                   Aichinger             123.8
# Aichinger 5 Beta - Bauträger Standard         Aichinger             123.8
# ...                                                 ...               ...
# Glan 5Mob Beta - Bauträger Standard                Glan           38994.0
# Glan 6Mob Beta - Aktuell                           Glan           38994.0
# Glan 7Mob Beta - Netzdienlichkeit                  Glan           38994.0
# Glan 8Mob Beta - Min PEQ                           Glan           38994.0
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom       Glan           38994.0
#
#                                               Büro NGF (m²)  Schule NGF (m²)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                  0.0              0.0
# Aichinger 2 Alpha - Aktuell                             0.0              0.0
# Aichinger 3 Alpha - Netzdienlichkeit                    0.0              0.0
# Aichinger 4 Alpha - Min PEQ                             0.0              0.0
# Aichinger 5 Beta - Bauträger Standard                   0.0              0.0
# ...                                                     ...              ...
# Glan 5Mob Beta - Bauträger Standard                     0.0              0.0
# Glan 6Mob Beta - Aktuell                                0.0              0.0
# Glan 7Mob Beta - Netzdienlichkeit                       0.0              0.0
# Glan 8Mob Beta - Min PEQ                                0.0              0.0
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom            0.0              0.0
#
#                                               Kiga NGF (m²)  ...  Beta  Omega  \
# longname                                                     ...
# Aichinger 1 Alpha - Bauträger Standard                  0.0  ...
# Aichinger 2 Alpha - Aktuell                             0.0  ...
# Aichinger 3 Alpha - Netzdienlichkeit                    0.0  ...
# Aichinger 4 Alpha - Min PEQ                             0.0  ...
# Aichinger 5 Beta - Bauträger Standard                   0.0  ...  Beta
# ...                                                     ...  ...   ...    ...
# Glan 5Mob Beta - Bauträger Standard                   502.0  ...  Beta
# Glan 6Mob Beta - Aktuell                              502.0  ...  Beta
# Glan 7Mob Beta - Netzdienlichkeit                     502.0  ...  Beta
# Glan 8Mob Beta - Min PEQ                              502.0  ...  Beta
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom          502.0  ...  Beta
#
#                                               Systemgrenze  id  Energiesystem  \
# longname
# Aichinger 1 Alpha - Bauträger Standard               Alpha   1      Fernwärme
# Aichinger 2 Alpha - Aktuell                          Alpha   2     Wärmepumpe
# Aichinger 3 Alpha - Netzdienlichkeit                 Alpha   3     WP mit DSM
# Aichinger 4 Alpha - Min PEQ                          Alpha   4     WP mit DSM
# Aichinger 5 Beta - Bauträger Standard                 Beta   5      Fernwärme
# ...                                                    ...  ..            ...
# Glan 5Mob Beta - Bauträger Standard                   Beta   5      Fernwärme
# Glan 6Mob Beta - Aktuell                              Beta   6     Wärmepumpe
# Glan 7Mob Beta - Netzdienlichkeit                     Beta   7     WP mit DSM
# Glan 8Mob Beta - Min PEQ                              Beta   8     WP mit DSM
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom          Beta   8     WP mit DSM
#
#                                               saldo_offset    PE_Saldo  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                   0  -38.335596
# Aichinger 2 Alpha - Aktuell                             20   91.841831
# Aichinger 3 Alpha - Netzdienlichkeit                    84  146.291772
# Aichinger 4 Alpha - Min PEQ                             84  138.033751
# Aichinger 5 Beta - Bauträger Standard                    0  -44.318619
# ...                                                    ...         ...
# Glan 5Mob Beta - Bauträger Standard                      0  -71.976424
# Glan 6Mob Beta - Aktuell                                20   -6.228717
# Glan 7Mob Beta - Netzdienlichkeit                       84   10.268391
# Glan 8Mob Beta - Min PEQ                                84    6.892557
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom            84   20.219960
#
#                                              District Energy Balance  \
# longname
# Aichinger 1 Alpha - Bauträger Standard           SF Detached housing
# Aichinger 2 Alpha - Aktuell                      SF Detached housing
# Aichinger 3 Alpha - Netzdienlichkeit             SF Detached housing
# Aichinger 4 Alpha - Min PEQ                      SF Detached housing
# Aichinger 5 Beta - Bauträger Standard            SF Detached housing
# ...                                                              ...
# Glan 5Mob Beta - Bauträger Standard                Urban residential
# Glan 6Mob Beta - Aktuell                           Urban residential
# Glan 7Mob Beta - Netzdienlichkeit                  Urban residential
# Glan 8Mob Beta - Min PEQ                           Urban residential
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom       Urban residential
#
#                                               Floor area ratio (FAR)  \
# longname
# Aichinger 1 Alpha - Bauträger Standard                      0.234899
# Aichinger 2 Alpha - Aktuell                                 0.234899
# Aichinger 3 Alpha - Netzdienlichkeit                        0.234899
# Aichinger 4 Alpha - Min PEQ                                 0.234899
# Aichinger 5 Beta - Bauträger Standard                       0.234899
# ...                                                              ...
# Glan 5Mob Beta - Bauträger Standard                         1.046626
# Glan 6Mob Beta - Aktuell                                    1.046626
# Glan 7Mob Beta - Netzdienlichkeit                           1.046626
# Glan 8Mob Beta - Min PEQ                                    1.046626
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom                1.046626
#
#                                               Primary Energy balance
# longname
# Aichinger 1 Alpha - Bauträger Standard                    -38.335596
# Aichinger 2 Alpha - Aktuell                                91.841831
# Aichinger 3 Alpha - Netzdienlichkeit                      146.291772
# Aichinger 4 Alpha - Min PEQ                               138.033751
# Aichinger 5 Beta - Bauträger Standard                     -44.318619
# ...                                                              ...
# Glan 5Mob Beta - Bauträger Standard                       -71.976424
# Glan 6Mob Beta - Aktuell                                   -6.228717
# Glan 7Mob Beta - Netzdienlichkeit                          10.268391
# Glan 8Mob Beta - Min PEQ                                    6.892557
# Glan 8,5Mob Beta - Min PEQ - 75% Nutzerstrom               20.219960
#
# [88 rows x 421 columns]

# %%
zq_zielwert = Zielwert.ZQSynergy()
fsi = np.linspace(0,5,100)
zw_df = pd.DataFrame()
zw_df["Target for PED Alpha = - Context factor density"] = zq_zielwert.df(fsi)
zw_df[""] = np.zeros(len(fsi))
zw_df2 = pd.DataFrame()
zw_df2["Density context factor" "\n" "added or subtracted" "\n" "to PE-balance"] = zq_zielwert.df(fsi)
zw_df2[""] = np.zeros(len(fsi))

fig, ax = plt.subplots(1,1, figsize=(7,4.3))

target_of_gfz(ax, df=zw_df, xlims=(0,5), ylims=(-150,200), color=["red", "darkred"])
for i, proj in enumerate(df_plot.Projekt.unique()):
    df_proj = df_plot[df_plot.Projekt==proj]
    # GFZ marks
    minpeq = df_proj[df_proj["Variantenname"]=="Min PEQ"]["PE_Saldo"][0]
    gfz = df_proj.GFZ.unique()[0]

    #gfz lines
    ax.plot((gfz, gfz),(-150,minpeq), linewidth=0.1, color="grey")
    ax.text(gfz-0.1, -150-(10*(i%2)), round(gfz,2), fontsize=8)

    # min peq bubble
    #zw = zq_zielwert.alpha(gfz)
    #ax.plot((gfz, gfz), (zw, minpeq), color="red", linewidth=0.6)

    d=0
    if proj in ["Am Bichl", "Gneis"]:
        d = 20
    #beschriftung MIn PEQ
    s = f"{proj}: {round(minpeq)} (+{round(minpeq-zw)})"
    # s = f"{proj} "
    #ax.text(gfz+0.1, minpeq+d, s, fontsize=11)

df_plot = df[df.Systemgrenze=="Alpha"]
df_plot.Variantenname = df_plot.Variantenname.str\
    .replace("Alpha - ","")\
    .replace("Standard","")\
    .replace("Bauträger Standard", "Property developer" "\n" "standard")\
    .replace("Aktuell", "Current status of planning")\
    .replace("Netzdienlichkeit", "Network utility")
#    .replace("Beta - ","")\
 #   .replace("Standard","")\
  #  .replace("Min PEQ", "Min PED")\
   # .replace("Min PEQ - 75% Nutzerstrom", "Min PED - 75% User electricity demand")\
    #.replace("Bauträger", "Property developer")

    
#sns.set(font_scale=1, style="whitegrid", font="Palatino Linotype")

sns.set(font="Palatino Linotype", style="whitegrid")
sns.scatterplot(x="Floor area ratio (FAR)", y="Primary Energy balance", data=df[df.Systemgrenze=="Alpha"], hue="District Energy Balance")

ax.set_ylabel("Primary Energy Balance\nkWh/m²NFAa", font="Palatino Linotype")
ax.set_xlabel("Floor Area Ratio (FAR) [-]", font="Palatino Linotype")

# sns.scatterplot(x=2.9, y=[25, -57, -82], data=[25, -57, -82], color="blue")
# sns.scatterplot(x=4.0, y=[31, -48, -79], data=[31, -48, -79], color="blue")
# sns.scatterplot(x=1.0, y=[-24, -108, -84], data=[-24, -108, -84], color="blue")
#
# sns.scatterplot(x=1.3, y=[8, -135, -143], data=[8, -135, -143], color="green")
# sns.scatterplot(x=2.9, y=[25, -261, -286], data=[25, -261, -286], color="green")
# sns.scatterplot(x=4.0, y=[31, -141, -172], data=[31, -141, -172], color="green")
# sns.scatterplot(x=1.0, y=[-24, -238, -214], data=[-24, -238, -214], color="green")

plt.savefig("P2_zqProjects.png", dpi=300)
# Out:
# C:\Users\Simon Schneider\AppData\Local\Temp\ipykernel_39132\344019439.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot.Variantenname = df_plot.Variantenname.str\

# %%
zq_zielwert = Zielwert.ZQSynergy()
fsi = np.linspace(0,5,100)
zw_df = pd.DataFrame()
zw_df["Green-field PED Balance Target = - Context factor density"] = zq_zielwert.df(fsi)
zw_df["Positive Balance Target w/o context factor"] = np.zeros(len(fsi))

fig, ax = plt.subplots(1,1, figsize=(7,4.3))

sns.set("paper", font="Times new roman", style="whitegrid", )
target_of_gfz(ax, df=zw_df, xlims=(0,5), ylims=(-150,200), color=["Darkgreen", "darkred"])

for i, proj in enumerate(df_plot.Projekt.unique()):
    df_proj = df_plot[df_plot.Projekt==proj]
    # GFZ marks
    minpeq = df_proj[df_proj["Variantenname"]=="Min PEQ"]["PE_Saldo"][0]
    gfz = df_proj.GFZ.unique()[0]

    #gfz lines
    ax.plot((gfz, gfz),(-150,minpeq), linewidth=0.1, color="grey")
    ax.text(gfz-0.1, -150-(10*(i%2)), round(gfz,2), fontsize=8)

    # min peq bubble
    #zw = zq_zielwert.alpha(gfz)
    #ax.plot((gfz, gfz), (zw, minpeq), color="red", linewidth=0.6)

    d=0
    if proj in ["Am Bichl", "Gneis"]:
        d = 20
    #beschriftung MIn PEQ
    s = f"{proj}: {round(minpeq)} (+{round(minpeq-zw)})"
    # s = f"{proj} "
    #ax.text(gfz+0.1, minpeq+d, s, fontsize=11)


#sns.set(font_scale=1, style="whitegrid", font="Palatino Linotype")

df_plot = df[df.Systemgrenze=="Alpha"]
df_plot.Variantenname = df_plot.Variantenname.str\
    .replace("Alpha - ","")\
    .replace("Standard","")\
    .replace("Bauträger Standard", "Property developer" "\n" "standard")\
    .replace("Aktuell", "Current status of planning")\
    .replace("Netzdienlichkeit", "Network utility")
#    .replace("Beta - ","")\
 #   .replace("Standard","")\
  #  .replace("Min PEQ", "Min PED")\
   # .replace("Min PEQ - 75% Nutzerstrom", "Min PED - 75% User electricity demand")\
    #.replace("Bauträger", "Property developer")

sns.scatterplot(x="GFZ", y="PE_Saldo", data=df_plot, ax=ax, color="lightgreen", label="Potential green-field PED configurations")
#sns.scatterplot(x="GFZ", y="PE_Saldo", data=df_plot, ax=ax, color="lightgreen", hue="Variantenname", palette="grey")

sns.scatterplot(x="GFZ", y="PE_Saldo", data=df_plot[df_plot.Variantenname=="Min PEQ"],
                ax=ax, color="green", label="Technically feasible Green-field PED configuration of similar ambition")

ax.set_ylabel("Primary Energy Balance\nkWh/m²NFAa", font="Palatino Linotype")
ax.set_xlabel("Floor Area Ratio (FAR) [-]", font="Palatino Linotype")

# sns.scatterplot(x=2.9, y=[25, -57, -82], data=[25, -57, -82], color="blue")
# sns.scatterplot(x=4.0, y=[31, -48, -79], data=[31, -48, -79], color="blue")
# sns.scatterplot(x=1.0, y=[-24, -108, -84], data=[-24, -108, -84], color="blue")
#
# sns.scatterplot(x=1.3, y=[8, -135, -143], data=[8, -135, -143], color="green")
# sns.scatterplot(x=2.9, y=[25, -261, -286], data=[25, -261, -286], color="green")
# sns.scatterplot(x=4.0, y=[31, -141, -172], data=[31, -141, -172], color="green")
# sns.scatterplot(x=1.0, y=[-24, -238, -214], data=[-24, -238, -214], color="green")

plt.savefig("PVSEc.png", dpi=300)
# Out:
# C:\Users\Simon Schneider\AppData\Local\Temp\ipykernel_39132\2403126934.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plot.Variantenname = df_plot.Variantenname.str\
