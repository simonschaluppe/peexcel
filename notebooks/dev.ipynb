# %%
import pexl
pexl.glossary.Qdhw_1_distr_losses.formula
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pexl
# ----> 2 pexl.glossary.Qdhw_1_distr_losses.formula
#
# AttributeError: 'VariableMeta' object has no attribute 'formula'
