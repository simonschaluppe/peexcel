# %%
# %reload_ext autoreload
# %autoreload 2
 
from pexl.io.csv import read_dataset_dir, normalize_table

tables = read_dataset_dir("../data/schemas/dev")

# %%
tables["IN"].head()
# Out:
#                 var_name ka       Type  ... Icon    Formel    bind_type
# 0           project_name  2  userinput  ...    📝   🏙️!$D$5  formula_ref
# 1            project_url  2  userinput  ...    📝     🏙️!D6  formula_ref
# 2       location_address  2  userinput  ...    📝  🏙️!$D$12  formula_ref
# 3      municipality_name  2  userinput  ...    📝    🏙️!D14  formula_ref
# 4  project_creation_date  2  userinput  ...    📝   🏙️!$D$7  formula_ref
#
# [5 rows x 9 columns]

# %%
tables["OUT"].head()
# Out:
#         var_name ID           Kategorie  ...     Einheit Label Kommentar
# 0  UED_plugloads     Nutzenergiebedarfe  ...  kWh/m²NGFa
# 1   UED_lighting     Nutzenergiebedarfe  ...  kWh/m²NGFa
# 2  UED_auxiliary     Nutzenergiebedarfe  ...  kWh/m²NGFa
# 3    UED_heating     Nutzenergiebedarfe  ...  kWh/m²NGFa
# 4    UED_cooling     Nutzenergiebedarfe  ...  kWh/m²NGFa
#
# [5 rows x 8 columns]

# %%
norm_in = normalize_table(tables["IN"], key_cols=["var_name"])
norm_out = normalize_table(tables["OUT"], key_cols=["var_name"])

norm_out.head()
# Out:
#                 var_name ID        Kategorie  ...     Einheit Label Kommentar
# 0               Batt_FEC     Batterienutzung  ...           x
# 1               Batt_RTE     Batterienutzung  ...
# 2     Batt_charge_losses     Batterienutzung  ...  kWh/m²NGFa
# 3  Batt_discharge_losses     Batterienutzung  ...  kWh/m²NGFa
# 4         Batt_to_Ec_min           EE-Bilanz  ...  kWh/m²NGFa
#
# [5 rows x 8 columns]

# %%
from pexl.io.converter import xlsx_to_dataset_dir

xlsx_to_dataset_dir(
    "../data/exports/schema.xlsx",
    "../data/schemas/dev",
    mode="schema",
)
# Out:
# ConvertResult(out_dir=WindowsPath('../data/schemas/dev'), written={'IN': WindowsPath('../data/schemas/dev/IN.csv'), 'OUT': WindowsPath('../data/schemas/dev/OUT.csv')}, audit_path=WindowsPath('../data/schemas/dev/AUDIT.json'))

# %%
xlsx_to_dataset_dir(
    "../data/exports/schema.xlsx",
    "../data/schemas_raw/dev2",
    mode="raw",
)
# Out:
# ConvertResult(out_dir=WindowsPath('../data/schemas_raw/dev2'), written={'IN': WindowsPath('../data/schemas_raw/dev2/IN.csv'), 'OUT': WindowsPath('../data/schemas_raw/dev2/OUT.csv')}, audit_path=None)

# %%
xlsx_to_dataset_dir(
    "../data/schemas/dev/ka_schema_new.xlsx",
    "../data/schemas/dev",
    mode="schema",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 xlsx_to_dataset_dir(
#       2     "../data/schemas/dev/ka_schema_new.xlsx",
#       3     "../data/schemas/dev",
#       4     mode="schema",
#       5     overwrite="overwrite",
#       6 )
#
# File ~\code\peexcel\src\pexl\io\converter.py:78, in xlsx_to_dataset_dir(xlsx_path, out_dir, sheets, mode, delimiter, encoding, overwrite)
#      75     raise ValueError(f"Invalid mode={mode!r}. Use 'schema' or 'raw'.")
#      77 for table_name, sheet_name in sheets.items():
# ---> 78     df = pd.read_excel(xlsx_path, sheet_name=sheet_name, dtype=str).fillna("")
#      80     if mode == "schema":
#      81         df, table_audit = _clean_for_schema_contract(df)
#
# ...
