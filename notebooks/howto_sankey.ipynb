# %%
from pexl import Project

project = Project.example()
project, project.scenarios
# Out:
# (<Project scenarios=1 warnings=0 source=WindowsPath('C:/Users/schneids/code/peexcel/data/exports/development_examples.xlsx')>,
#  [<Scenario column='Beispiel | Alle Energiesysteme' project='Beispiel' name='Alle Energiesysteme'>])

# %%
from pexl.reporting.sankeys import DHW_SYSTEM
from pexl.plot.sankey import to_frame, render

# %%
scenario = project.scenarios[0]

fig = render(scenario, DHW_SYSTEM)
fig.show()

# %%
#english?
fig = render(scenario, DHW_SYSTEM, language="en")
fig.show()

# %%
from pexl.reporting.sankeys import HEATING_SYSTEM

render(scenario, HEATING_SYSTEM).show()

# %%
from pexl.reporting.sankeys import COOLING_SYSTEM

render(scenario, COOLING_SYSTEM).show()
