# %%
from pexl.io.converter import xlsx_to_dataset_dir

version = "v1_11_4"

xlsx_to_dataset_dir(
    f"../data/exports/schema_{version}.xlsx", # created by PEExcel macro "export_schema"
    f"../data/schemas/{version}", #creates this directory and csv files
    mode="schema",
    replace_files=True # careful!
)
# Out:
# ConvertResult(out_dir=WindowsPath('../data/schemas/v1_11_4'), written={'IN': WindowsPath('../data/schemas/v1_11_4/IN.csv'), 'OUT': WindowsPath('../data/schemas/v1_11_4/OUT.csv'), 'SIM': WindowsPath('../data/schemas/v1_11_4/SIM.csv')}, audit_path=WindowsPath('../data/schemas/v1_11_4/AUDIT.json'))

# %%
from pexl.validate.schema import diff_schema_dirs

diff_result = diff_schema_dirs(
    old_dir=f"../data/schemas/v1.10_4",
    new_dir= f"../data/schemas/{version}"
)
diff_result
# Out:
# {'meta': {'old_dir': '..\\data\\schemas\\v1.10_4',
#   'new_dir': '..\\data\\schemas\\v1_11_4',
#   'key_col': 'var_name'},
#  'tables': {'IN': {'columns': {'added': ['comment',
#      'domain',
#      'entity_group',
#      'entity_key',
#      'icon',
#      'label_de',
#      'measure',
#      'spatial_scope',
#      'temporal_scope',
#      'unit'],
#     'removed': ['Einheit', 'Icon', 'Kommentar', 'Name', 'Type'],
#     'common_count': 3},
#    'rows': {'old_count': 612,
#     'new_count': 617,
#     'new_errors': 6,
#     'var_name_added': ['transmittance_fundament_Wm2NFA',
#      'transmittance_heatbridge_Wm2NFA',
#      'transmittance_roof_Wm2NFA',
#      'transmittance_walls_Wm2NFA',
#      'transmittance_windows_Wm2NFA'],
#     'var_name_removed': [],
#     'duplicate_keys_old': [],
#     'duplicate_keys_new': []},
#    'changes': {'compared_columns': ['ka', 'Formel'],
#     'value_error_count': 6,
#     'value_change_count': 67,
#     'value_errors': [{'var_name': 'fGHG_grid_column',
#       'column': 'Formel',
#       'old': 'VERGLEICH(fGHG_grid_profile;fGHG[#Kopfzeilen];0)',
#       'new': 'VERGLEICH(fGHG_grid_profile;fGHG[#Kopfzeilen];0)'},
#      {'var_name': 'fPE_grid_column',
#       'column': 'Formel',
#       'old': 'VERGLEICH(fPE_grid_profile;fPE[#Kopfzeilen];0)',
#       'new': 'VERGLEICH(fPE_grid_profile;fPE[#Kopfzeilen];0)'},
#      {'var_name': 'flex_Signals_selected_column',
#       'column': 'Formel',
#       'old': 'VERGLEICH(FLEX_signal_name;Signals[#Kopfzeilen];0)',
#       'new': 'VERGLEICH(FLEX_signal_name;Signals[#Kopfzeilen];0)'},
#      {'var_name': 'rcp1_dh',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp1_renewable;#NV);rcp1_fossil)',
#       'new': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp1_renewable;#NV);rcp1_fossil)'},
#      {'var_name': 'rcp2_dh',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp2_renewable;#NV);rcp2_fossil)',
#       'new': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp2_renewable;#NV);rcp2_fossil)'},
#      {'var_name': 'rcp3_dh',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp3_renewable;#NV);rcp3_fossil)',
#       'new': 'WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp3_renewable;#NV);rcp3_fossil)'}],
#     'value_changes': [{'var_name': 'ACH_night_m³',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K185:K191;K67:K73;K46:K52;SVERWEIS(K196:K202;night_ventilation_types;2;FALSCH))',
#       'new': 'SUMMENPRODUKT(N185:N191;N67:N73;N46:N52;SVERWEIS(N196:N202;night_ventilation_types;2;FALSCH))'},
#      {'var_name': 'DHW_Tmax',
#       'column': 'Formel',
#       'old': 'MIN(K401;DHW_Tmax_constant)',
#       'new': 'MIN(N401;DHW_Tmax_constant)'},
#      {'var_name': 'DHW_storage_1_liter',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K403:K409;K410:K416)',
#       'new': 'SUMMENPRODUKT(N403:N409;N410:N416)'},
#      {'var_name': 'DHW_storage_2_liter',
#       'column': 'Formel',
#       'old': 'SUMME(K410:K416)-DHW_storage_1_liter',
#       'new': 'SUMME(N410:N416)-DHW_storage_1_liter'},
#      {'var_name': 'EV_charging_losses_surcharge_factor',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(1/K523;0)',
#       'new': 'WENNFEHLER(1/N523;0)'},
#      {'var_name': 'EV_selfdischarge_per_h',
#       'column': 'Formel',
#       'old': 'K520/24/7',
#       'new': 'N520/24/7'},
#      {'var_name': 'EV_storage_total_kWh',
#       'column': 'Formel',
#       'old': 'K518*K515',
#       'new': 'N518*N515'},
#      {'var_name': 'FLEX_cool1_use',
#       'column': 'Formel',
#       'old': 'WENN(K480="System 1";WAHR;FALSCH)',
#       'new': 'WENN(N480="System 1";WAHR;FALSCH)'},
#      {'var_name': 'FLEX_cool3_use',
#       'column': 'Formel',
#       'old': 'WENN(K480="System 3";WAHR;FALSCH)',
#       'new': 'WENN(N480="System 3";WAHR;FALSCH)'},
#      {'var_name': 'FLEX_heat1_use',
#       'column': 'Formel',
#       'old': 'WENN(K475="System 1";WAHR;FALSCH)',
#       'new': 'WENN(N475="System 1";WAHR;FALSCH)'},
#      {'var_name': 'FLEX_heat3_use',
#       'column': 'Formel',
#       'old': 'WENN(K475="System 3";WAHR;FALSCH)',
#       'new': 'WENN(N475="System 3";WAHR;FALSCH)'},
#      {'var_name': 'FSI',
#       'column': 'Formel',
#       'old': 'GFA_total/K55',
#       'new': 'GFA_total/N55'},
#      {'var_name': 'GFA_total',
#       'column': 'Formel',
#       'old': 'SUMME(K30:K36)',
#       'new': 'SUMME(N30:N36)'},
#      {'var_name': 'GFV',
#       'column': 'Formel',
#       'old': 'NFA_total*(rh_avg+K78)',
#       'new': 'NFA_total*(rh_avg+N78)'},
#      {'var_name': 'GWP_miv_count_ev',
#       'column': 'Formel',
#       'old': 'K615*EV_share',
#       'new': 'N615*EV_share'},
#      {'var_name': 'GWP_miv_count_fossile',
#       'column': 'Formel',
#       'old': 'K615-K616',
#       'new': 'N615-N616'},
#      {'var_name': 'GWP_refratio_ceilings',
#       'column': 'Formel',
#       'old': 'K572/GFA_total',
#       'new': 'N572/GFA_total'},
#      {'var_name': 'GWP_refratio_fundament',
#       'column': 'Formel',
#       'old': 'K571/GFA_total',
#       'new': 'N571/GFA_total'},
#      {'var_name': 'GWP_refratio_roof',
#       'column': 'Formel',
#       'old': 'K570/GFA_total',
#       'new': 'N570/GFA_total'},
#      {'var_name': 'GWP_refratio_walls',
#       'column': 'Formel',
#       'old': 'K568/GFA_total',
#       'new': 'N568/GFA_total'},
#      {'var_name': 'GWP_refratio_windows',
#       'column': 'Formel',
#       'old': 'K569/GFA_total',
#       'new': 'N569/GFA_total'},
#      {'var_name': 'NFA_cooled',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K361:K367;K46:K52)',
#       'new': 'SUMMENPRODUKT(N361:N367;N46:N52)'},
#      {'var_name': 'NFA_mechvent',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K$178:K$184;K46:K52)',
#       'new': 'SUMMENPRODUKT(N$178:N$184;N46:N52)'},
#      {'var_name': 'NFA_office',
#       'column': 'Formel',
#       'old': 'K31*K39',
#       'new': 'N31*N39'},
#      {'var_name': 'NFA_other',
#       'column': 'Formel',
#       'old': 'K36*K44',
#       'new': 'N36*N44'},
#      {'var_name': 'NFA_residential',
#       'column': 'Formel',
#       'old': 'K30*K38',
#       'new': 'N30*N38'},
#      {'var_name': 'NFA_retailfood',
#       'column': 'Formel',
#       'old': 'K34*K42',
#       'new': 'N34*N42'},
#      {'var_name': 'NFA_retailother',
#       'column': 'Formel',
#       'old': 'K35*K43',
#       'new': 'N35*N43'},
#      {'var_name': 'NFA_schoolprim',
#       'column': 'Formel',
#       'old': 'K33*K41',
#       'new': 'N33*N41'},
#      {'var_name': 'NFA_schoolsec',
#       'column': 'Formel',
#       'old': 'K32*K40',
#       'new': 'N32*N40'},
#      {'var_name': 'NFA_total',
#       'column': 'Formel',
#       'old': 'SUMME(K46:K52)',
#       'new': 'SUMME(N46:N52)'},
#      {'var_name': 'NFAfrac_u',
#       'column': 'Formel',
#       'old': '1-K376',
#       'new': '1-N376'},
#      {'var_name': 'NFV_c',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K46:K52;K67:K73;cool_active_shares)',
#       'new': 'SUMMENPRODUKT(N46:N52;N67:N73;cool_active_shares)'},
#      {'var_name': 'NFV_mechvent',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K$178:K$184;K46:K52;K67:K73)',
#       'new': 'SUMMENPRODUKT(N$178:N$184;N46:N52;N67:N73)'},
#      {'var_name': 'NFV_u',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K46:K52;K67:K73;cool_passive_shares)',
#       'new': 'SUMMENPRODUKT(N46:N52;N67:N73;cool_passive_shares)'},
#      {'var_name': 'NFV_windowvent',
#       'column': 'Formel',
#       'old': 'NFV_total-K195',
#       'new': 'NFV_total-N195'},
#      {'var_name': 'QC_generation_eff_2th',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(1/K388;0)',
#       'new': 'WENNFEHLER(1/N388;0)'},
#      {'var_name': 'QC_to_EC_1',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(1/K387;0)',
#       'new': 'WENNFEHLER(1/N387;0)'},
#      {'var_name': 'QC_to_EC_3',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(1/K389;0)',
#       'new': 'WENNFEHLER(1/N389;0)'},
#      {'var_name': 'QHmax_room_MW',
#       'column': 'Formel',
#       'old': 'K323*K53/1000000',
#       'new': 'N323*N53/1000000'},
#      {'var_name': 'Tsetcool_flex',
#       'column': 'Formel',
#       'old': 'Tsetcool_max-K478',
#       'new': 'Tsetcool_max-N478'},
#      {'var_name': 'Tsetheat_flex',
#       'column': 'Formel',
#       'old': 'Tsetheat_min+K473',
#       'new': 'Tsetheat_min+N473'},
#      {'var_name': 'Vent_share_mech_cooled',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(SUMMENPRODUKT(K46:K52;cool_active_shares;MTRANS(vent_mech_shares);K67:K73)/NFV_total;0)',
#       'new': 'WENNFEHLER(SUMMENPRODUKT(N46:N52;cool_active_shares;MTRANS(vent_mech_shares);N67:N73)/NFV_total;0)'},
#      {'var_name': 'Vent_share_mech_uncooled',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(SUMMENPRODUKT(K46:K52;cool_passive_shares;MTRANS(vent_mech_shares);K67:K73)/NFV_total;0)',
#       'new': 'WENNFEHLER(SUMMENPRODUKT(N46:N52;cool_passive_shares;MTRANS(vent_mech_shares);N67:N73)/NFV_total;0)'},
#      {'var_name': 'Vent_share_window_cooled',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(SUMMENPRODUKT(K46:K52;cool_active_shares;MTRANS(vent_window_shares);K67:K73)/NFV_total;0)',
#       'new': 'WENNFEHLER(SUMMENPRODUKT(N46:N52;cool_active_shares;MTRANS(vent_window_shares);N67:N73)/NFV_total;0)'},
#      {'var_name': 'Vent_share_window_uncooled',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(SUMMENPRODUKT(K46:K52;cool_passive_shares;MTRANS(vent_window_shares);K67:K73)/NFV_total;0)',
#       'new': 'WENNFEHLER(SUMMENPRODUKT(N46:N52;cool_passive_shares;MTRANS(vent_window_shares);N67:N73)/NFV_total;0)'},
#      {'var_name': 'cool_th2_is_other',
#       'column': 'Formel',
#       'old': '--NICHT(ODER(K661;K666;K671))',
#       'new': '--NICHT(ODER(N661;N666;N671))'},
#      {'var_name': 'dhw1_is_other',
#       'column': 'Formel',
#       'old': '--UND(NICHT(ODER(K662;K667;K672)); DHW_1_is_used)',
#       'new': '--UND(NICHT(ODER(N662;N667;N672)); DHW_1_is_used)'},
#      {'var_name': 'dhw2_is_other',
#       'column': 'Formel',
#       'old': '--UND(NICHT(ODER(K663;K668;K673));DHW_2_is_used)',
#       'new': '--UND(NICHT(ODER(N663;N668;N673));DHW_2_is_used)'},
#      {'var_name': 'fc_c',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K152:K158;K46:K52;cool_active_shares)*per_NFA_cooled',
#       'new': 'SUMMENPRODUKT(N152:N158;N46:N52;cool_active_shares)*per_NFA_cooled'},
#      {'var_name': 'fc_u',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K152:K158;K46:K52;cool_passive_shares)*per_NFA_uncooled',
#       'new': 'SUMMENPRODUKT(N152:N158;N46:N52;cool_passive_shares)*per_NFA_uncooled'},
#      {'var_name': 'heat_th2_is_other',
#       'column': 'Formel',
#       'old': '--NICHT(ODER(K659;K664;K669))',
#       'new': '--NICHT(ODER(N659;N664;N669))'},
#      {'var_name': 'heat_th4_is_other',
#       'column': 'Formel',
#       'old': '--NICHT(ODER(K660;K665;K670))',
#       'new': '--NICHT(ODER(N660;N665;N670))'},
#      {'var_name': 'hull_window_m2',
#       'column': 'Formel',
#       'old': 'SUMME(K83:K86)',
#       'new': 'SUMME(N83:N86)'},
#      {'var_name': 'input_version_number',
#       'column': 'ka',
#       'old': '0',
#       'new': '1'},
#      {'var_name': 'mobility_region',
#       'column': 'Formel',
#       'old': 'WENNFEHLER(SVERWEIS(K22;gemeinden;3;FALSCH)&WENN(mobility_mode="Vereinfacht";" optimiert";""); "Keine Region ausgewählt.")',
#       'new': 'WENNFEHLER(SVERWEIS(N22;gemeinden;3;FALSCH)&WENN(mobility_mode="Vereinfacht";" optimiert";""); "Keine Region ausgewählt.")'},
#      {'var_name': 'rh_avg',
#       'column': 'Formel',
#       'old': 'SUMMENPRODUKT(K67:K73;K46:K52)/NFA_total',
#       'new': 'SUMMENPRODUKT(N67:N73;N46:N52)/NFA_total'},
#      {'var_name': 'scenario_version', 'column': 'ka', 'old': '0', 'new': '1'},
#      {'var_name': 'transmittance_Wm2',
#       'column': 'Formel',
#       'old': 'SUMME(K110:K114)',
#       'new': 'SUMME(N110:N114)'},
#      {'var_name': 'vent_infiltration_ACH',
#       'column': 'Formel',
#       'old': 'K175/K176',
#       'new': 'N175/N176'},
#      {'var_name': 'vent_scale_office',
#       'column': 'Formel',
#       'old': 'K205/MAX(Nutzung_Büro[Bedarf Luftwechsel])',
#       'new': 'N205/MAX(Nutzung_Büro[Bedarf Luftwechsel])'},
#      {'var_name': 'vent_scale_residential',
#       'column': 'Formel',
#       'old': 'K204/MAX(Nutzung_Wohnen[Bedarf Luftwechsel])',
#       'new': 'N204/MAX(Nutzung_Wohnen[Bedarf Luftwechsel])'},
#      {'var_name': 'vent_scale_retail',
#       'column': 'Formel',
#       'old': 'K209/MAX(Nutzung_Handel_NonFood[Bedarf Luftwechsel])',
#       'new': 'N209/MAX(Nutzung_Handel_NonFood[Bedarf Luftwechsel])'},
#      {'var_name': 'vent_scale_school_prim',
#       'column': 'Formel',
#       'old': 'K207/MAX(Nutzung_KIGA[Bedarf Luftwechsel])',
#       'new': 'N207/MAX(Nutzung_KIGA[Bedarf Luftwechsel])'},
#      {'var_name': 'vent_scale_school_sec',
#       'column': 'Formel',
#       'old': 'K206/MAX(Nutzung_Schule[Bedarf Luftwechsel])',
#       'new': 'N206/MAX(Nutzung_Schule[Bedarf Luftwechsel])'},
#      {'var_name': 'vent_scale_supermarket',
#       'column': 'Formel',
#       'old': 'K208/MAX(Nutzung_Handel_Food[Bedarf Luftwechsel])',
#       'new': 'N208/MAX(Nutzung_Handel_Food[Bedarf Luftwechsel])'},
#      {'var_name': 'weather_index',
#       'column': 'Formel',
#       'old': 'VERGLEICH(K28;list_weathers;0)',
#       'new': 'VERGLEICH(N28;list_weathers;0)'}],
#     'truncated': False}},
#   'OUT': {'columns': {'added': ['domain',
#      'entity_group',
#      'entity_key',
#      'icon',
#      'ka',
#      'label_de',
#      'measure',
#      'spatial_scope',
#      'temporal_scope',
#      'unit'],
#     'removed': ['Bereich',
#      'Einheit',
#      'Formel',
#      'Kategorie',
#      'Kommentar',
#      'Label',
#      'Name'],
#     'common_count': 1},
#    'rows': {'old_count': 410,
#     'new_count': 412,
#     'new_errors': 0,
#     'var_name_added': ['test_heat_balance_summer', 'test_heat_balance_winter'],
#     'var_name_removed': [],
#     'duplicate_keys_old': [],
#     'duplicate_keys_new': []},
#    'changes': {'compared_columns': [],
#     'value_error_count': 0,
#     'value_change_count': 0,
#     'value_errors': [],
#     'value_changes': [],
#     'truncated': False}},
#   'SIM': {'columns': {'added': [], 'removed': [], 'common_count': 2},
#    'rows': {'old_count': 394,
#     'new_count': 394,
#     'new_errors': 3,
#     'var_name_added': [],
#     'var_name_removed': [],
#     'duplicate_keys_old': [],
#     'duplicate_keys_new': []},
#    'changes': {'compared_columns': ['Formula'],
#     'value_error_count': 3,
#     'value_change_count': 0,
#     'value_errors': [{'var_name': 'Signal',
#       'column': 'Formula',
#       'old': '=INDEX(Signals,ROW()-ROW(Signals[#Headers]),flex_Signals_selected_column)',
#       'new': '=INDEX(Signals,ROW()-ROW(Signals[#Headers]),flex_Signals_selected_column)'},
#      {'var_name': 'Ti0cooled',
#       'column': 'Formula',
#       'old': '=IF(NFA_cooled/NFA_total>0,Tsetheat_min,#N/A)',
#       'new': '=IF(NFA_cooled/NFA_total>0,Tsetheat_min,#N/A)'},
#      {'var_name': 'Ti0uncooled',
#       'column': 'Formula',
#       'old': '=IF(1-NFA_cooled/NFA_total>0,Tsetheat_min,#N/A)',
#       'new': '=IF(1-NFA_cooled/NFA_total>0,Tsetheat_min,#N/A)'}],
#     'value_changes': [],
#     'truncated': False}}},
#  'audit': {'present': True,
#   'old': {'IN': {'empty_var_name_count': 88},
#    'OUT': {'empty_var_name_count': 98},
#    'SIM': {'empty_var_name_count': 0}},
#   'new': {'IN': {'empty_var_name_count': 82},
#    'OUT': {'empty_var_name_count': 102},
#    'SIM': {'empty_var_name_count': 0}},
#   'raw_old_present': True,
#   'raw_new_present': True}}

# %%
from pexl.validate.schema import schema_diff_to_markdown


md = schema_diff_to_markdown(diff_result, value_format="None")
print(md)
# Out:
# # Schema Diff
#
# - **Old:** `..\data\schemas\v1.10_4`
# - **New:** `..\data\schemas\v1_11_4`
# - **Key:** `var_name`
#
# ## IN
#
# ### Columns
# - Added: ['comment', 'domain', 'entity_group', 'entity_key', 'icon', 'label_de', 'measure', 'spatial_scope', 'temporal_scope', 'unit']
# - Removed: ['Einheit', 'Icon', 'Kommentar', 'Name', 'Type']
# - Common count: 3
#
# ### Rows
# Old count: 612
# New count: 617
# - **New Error count: 6**
# - Added/~~Removed~~ var_name:
#    - transmittance_fundament_Wm2NFA
#   - transmittance_heatbridge_Wm2NFA
#   - transmittance_roof_Wm2NFA
#   - transmittance_walls_Wm2NFA
#   - transmittance_windows_Wm2NFA
#
#
#
# ### Potential Errors (#)
#
# | var_name | column | error |
# |---|---|---|
# | fGHG_grid_column | Formel | VERGLEICH(fGHG_grid_profile;fGHG[#Kopfzeilen];0) |
# | fPE_grid_column | Formel | VERGLEICH(fPE_grid_profile;fPE[#Kopfzeilen];0) |
# | flex_Signals_selected_column | Formel | VERGLEICH(FLEX_signal_name;Signals[#Kopfzeilen];0) |
# | rcp1_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp1_renewable;#NV);rcp1_fossil) |
# | rcp2_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp2_renewable;#NV);rcp2_fossil) |
# | rcp3_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp3_renewable;#NV);rcp3_fossil) |
#
#
#
#
#
# ## OUT
#
# ### Columns
# - Added: ['domain', 'entity_group', 'entity_key', 'icon', 'ka', 'label_de', 'measure', 'spatial_scope', 'temporal_scope', 'unit']
# - Removed: ['Bereich', 'Einheit', 'Formel', 'Kategorie', 'Kommentar', 'Label', 'Name']
# - Common count: 1
#
# ### Rows
# Old count: 410
# New count: 412
# - **New Error count: 0**
# - Added/~~Removed~~ var_name:
#    - test_heat_balance_summer
#   - test_heat_balance_winter
#
#
#
# ### Potential Errors (#)
# - None
#
# ### Value changes
# - Compared columns: []
# - Error count: 0
# - Change count: 0
#
# _No value changes._
#
# ## SIM
#
# ### Columns
# - Added: []
# - Removed: []
# - Common count: 2
#
# ### Rows
# Old count: 394
# New count: 394
# - **New Error count: 3**
# - Added/~~Removed~~ var_name:
#
#
#
#
# ### Potential Errors (#)
#
# | var_name | column | error |
# |---|---|---|
# | Signal | Formula | =INDEX(Signals,ROW()-ROW(Signals[#Headers]),flex_Signals_selected_column) |
# | Ti0cooled | Formula | =IF(NFA_cooled/NFA_total>0,Tsetheat_min,#N/A) |
# | Ti0uncooled | Formula | =IF(1-NFA_cooled/NFA_total>0,Tsetheat_min,#N/A) |
#
# ### Value changes
# - Compared columns: ['Formula']
# - Error count: 3
# - Change count: 0
#
# _No value changes._
#
# ## Audit summary
#
# - Raw audit present (old): True
# - Raw audit present (new): True
#
# ### Empty var_name exclusions (converter)
#
# **Old:**
# ```json
# {'IN': {'empty_var_name_count': 88}, 'OUT': {'empty_var_name_count': 98}, 'SIM': {'empty_var_name_count': 0}}
# ```
# **New:**
# ```json
# {'IN': {'empty_var_name_count': 82}, 'OUT': {'empty_var_name_count': 102}, 'SIM': {'empty_var_name_count': 0}}
# ```

# %% [markdown]
# just copied into a markdown cell:

# %% [markdown]
# # Schema Diff
#
# - **Old:** `..\data\schemas\v1.10_4`
# - **New:** `..\data\schemas\v1_11_4`
# - **Key:** `var_name`
#
# ## IN
#
# ### Columns
# - Added: ['comment', 'domain', 'entity_group', 'entity_key', 'icon', 'label_de', 'measure', 'spatial_scope', 'temporal_scope', 'unit']
# - Removed: ['Einheit', 'Icon', 'Kommentar', 'Name', 'Type']
# - Common count: 3
#
# ### Rows
# Old count: 612
# New count: 617
# - **New Error count: 6**
# - Added/~~Removed~~ var_name:
#    - transmittance_fundament_Wm2NFA
#   - transmittance_heatbridge_Wm2NFA
#   - transmittance_roof_Wm2NFA
#   - transmittance_walls_Wm2NFA
#   - transmittance_windows_Wm2NFA
#
#
#
# ### Potential Errors (#)
#
# | var_name | column | error |
# |---|---|---|
# | fGHG_grid_column | Formel | VERGLEICH(fGHG_grid_profile;fGHG[#Kopfzeilen];0) |
# | fPE_grid_column | Formel | VERGLEICH(fPE_grid_profile;fPE[#Kopfzeilen];0) |
# | flex_Signals_selected_column | Formel | VERGLEICH(FLEX_signal_name;Signals[#Kopfzeilen];0) |
# | rcp1_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp1_renewable;#NV);rcp1_fossil) |
# | rcp2_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp2_renewable;#NV);rcp2_fossil) |
# | rcp3_dh | Formel | WENNFEHLER(WENN(FINDEN("rneuerbar";SVERWEIS(heat_th2_carrier_type;cf_constant;7;FALSCH));rcp3_renewable;#NV);rcp3_fossil) |
#
#
#
#
#
# ## OUT
#
# ### Columns
# - Added: ['domain', 'icon', 'ka', 'label_de', 'measure', 'spatial_scope', 'temporal_scope', 'unit']
# - Removed: ['Bereich', 'Einheit', 'Formel', 'Kategorie', 'Kommentar', 'Label', 'Name']
# - Common count: 1
#
# ### Rows
# Old count: 410
# New count: 410
# - **New Error count: 0**
# - Added/~~Removed~~ var_name:
#
#
#
#
# ### Potential Errors (#)
# - None
#
# ### Value changes
# - Compared columns: []
# - Error count: 0
# - Change count: 0
#
# _No value changes._
#
# ## SIM
#
# ### Columns
# - Added: []
# - Removed: []
# - Common count: 2
#
# ### Rows
# Old count: 394
# New count: 394
# - **New Error count: 3**
# - Added/~~Removed~~ var_name:
#
#
#
#
# ### Potential Errors (#)
#
# | var_name | column | error |
# |---|---|---|
# | Signal | Formula | =INDEX(Signals,ROW()-ROW(Signals[#Headers]),flex_Signals_selected_column) |
# | Ti0cooled | Formula | =IF(NFA_cooled/NFA_total>0,Tsetheat_min,#N/A) |
# | Ti0uncooled | Formula | =IF(1-NFA_cooled/NFA_total>0,Tsetheat_min,#N/A) |
#
# ### Value changes
# - Compared columns: ['Formula']
# - Error count: 3
# - Change count: 0
#
# _No value changes._
#
# ## Audit summary
#
# - Raw audit present (old): True
# - Raw audit present (new): True
#
# ### Empty var_name exclusions (converter)
#
# **Old:**
# ```json
# {'IN': {'empty_var_name_count': 88}, 'OUT': {'empty_var_name_count': 98}, 'SIM': {'empty_var_name_count': 0}}
# ```
# **New:**
# ```json
# {'IN': {'empty_var_name_count': 82}, 'OUT': {'empty_var_name_count': 98}, 'SIM': {'empty_var_name_count': 0}}
# ```

# %%
from pexl.schema.schema_codegen import generate_schema_module


generate_schema_module(
    excel_path=f"../data/exports/schema_{version}.xlsx",
    output_py_path=f"../src/pexl/schemas/generated/excel_{version.replace(".", "_")}.py",
    version=version.replace(".", "_"), # so filename is valid python module (no dots)
)

import pexl.schema.current as current_schema # latest schema must be manually set
current_schema.ExcelNamedVariables # is used by module excel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from pexl.schema.schema_codegen import generate_schema_module
#       4 generate_schema_module(
#       5     excel_path=f"../data/exports/schema_{version}.xlsx",
#       6     output_py_path=f"../src/pexl/schemas/generated/excel_{version.replace(".", "_")}.py",
#       7     version=version.replace(".", "_"), # so filename is valid python module (no dots)
#       8 )
#      10 import pexl.schema.current as current_schema # latest schema must be manually set
#
# ImportError: cannot import name 'generate_schema_module' from 'pexl.schema.schema_codegen' (C:\Users\schneids\code\peexcel\src\pexl\schema\schema_codegen.py)

# %%
from pexl.io.excel import read_project


project = read_project("../data/exports/ka_project_backup_v1.10.xlsx")
project

# %%
project.districts

# %%
d = project.get("EFHo")
print(d)
d.scenarios

# %%
a = d.scenarios[0]
b = d.get("nach 2020 - existing - Erdgas")
a,b

# %%
print(a.name)
print(a.v.project_description)
print(a.v.GFA_total, a.meta.GFA_total.unit, a.meta.GFA_total)
a.as_dict()
